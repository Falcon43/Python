# %% [markdown]
# # Getting started with OpenCV

# %% [markdown]
# ### Read an image
# Use the function cv2.imread() to read an image. The image should be in the working directory or a full path of image should be given.
#
#
# Second argument is a flag which specifies the way image should be read.
#
# cv2.IMREAD_COLOR : Loads a color image. Any transparency of image will be neglected. It is the default flag.
#
# cv2.IMREAD_GRAYSCALE : Loads image in grayscale mode
#
# cv2.IMREAD_UNCHANGED : Loads image as such including alpha channel
#
# Note Instead of these three flags, you can simply pass integers 1, 0 or -1 respectively.

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load an color image in grayscale
imgG = cv2.imread('train_1b.png',0)

# %% [markdown]
# ### Display an image
# Use the function cv2.imshow() to display an image in a window. The window automatically fits to the image size.
#
# First argument is a window name which is a string. second argument is our image. You can create as many windows as you wish, but with different window names.

# %%
# waitKey crashes with Jupyter
#cv2.imshow('image',img)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
print(imgG)   # grayscale 2D image
plt.imshow(imgG, cmap='gray')
# Out:
# [[128 128 128 ... 128 128 128]
#  [128 128 128 ... 128 128 128]
#  [128 128 128 ... 128 128 128]
#  ...
#  [128 128 128 ... 128 128 128]
#  [128 128 128 ... 128 128 128]
#  [128 128 128 ... 128 128 128]]

# %%
# Load a color image
img = cv2.imread('train_1b.png')
plt.imshow(img) #Read as BGR colormap
print(img)   # color 3D image
# Out:
# [[[128 128 128]
#   [128 128 128]
#   [128 128 128]
#   ...
#   [128 128 128]
#   [128 128 128]
#   [128 128 128]]
#
#  [[128 128 128]
#   [128 128 128]
#   [128 128 128]
#   ...
#   [128 128 128]
#   [128 128 128]
#   [128 128 128]]
#
#  [[128 128 128]
#   [128 128 128]
#   [128 128 128]
#   ...
#   [128 128 128]
#   [128 128 128]
#   [128 128 128]]
#
#  ...
#
#  [[128 128 128]
#   [128 128 128]
#   [128 128 128]
#   ...
#   [128 128 128]
#   [128 128 128]
#   [128 128 128]]
#
#  [[128 128 128]
#   [128 128 128]
#   [128 128 128]
#   ...
#   [128 128 128]
#   [128 128 128]
#   [128 128 128]]
#
#  [[128 128 128]
#   [128 128 128]
#   [128 128 128]
#   ...
#   [128 128 128]
#   [128 128 128]
#   [128 128 128]]]

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)) #Read as RGB colormap

# %%
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
flat = img.flatten()   # flatten is used with neural networks but id u r using CNN then keep the 3D image as input X
print(flat)
# Out:
# [128 128 128 ... 128 128 128]

# %%
img2 = cv2.imread('train_39c.png').flatten()

# %%
arr = []
arr.append(flat)
arr.append(img2)

# %%
print(arr)
# Out:
# [array([128, 128, 128, ..., 128, 128, 128], dtype=uint8), array([128, 128, 128, ..., 128, 128, 128], dtype=uint8)]

# %%
print(np.array(arr))
print(np.array(arr).shape)
# Out:
# [[128 128 128 ... 128 128 128]
#  [128 128 128 ... 128 128 128]]
# (2, 196608)

# %% [markdown]
# ### Write an image
# Use the function cv2.imwrite() to save an image.

# %%
cv2.imwrite('train_1b_grayscale.png',imgG)  #This will save the image in PNG format in the working directory.
# Out:
# True

# %% [markdown]
# # Drawing Functions in OpenCV
# Goal
# Learn to draw different geometric shapes with OpenCV
# You will learn these functions : cv2.line(), cv2.circle() , cv2.rectangle(), cv2.ellipse(), cv2.putText() etc.
#
# Code
# In all the above functions, you will see some common arguments as given below:
#
# img : The image where you want to draw the shapes
# color : Color of the shape. for BGR, pass it as a tuple, eg: (255,0,0) for blue. For grayscale, just pass the scalar value.
# thickness : Thickness of the line or circle etc. If -1 is passed for closed figures like circles, it will fill the shape. default thickness = 1
# lineType : Type of line, whether 8-connected, anti-aliased line etc. By default, it is 8-connected. cv2.LINE_AA gives anti-aliased line which looks great for curves.

# %% [markdown]
# ### Drawing Line
# To draw a line, you need to pass starting and ending coordinates of line.

# %%
# Draw a diagonal blue line with thickness of 5 px
img3 = cv2.imread('train_1b.png')
cv2.line(img3, (0,0), (200,200), (255,0,0), 5)
plt.imshow(img3)

# %% [markdown]
# ### Drawing Rectangle
# To draw a rectangle, you need top-left corner and bottom-right corner of rectangle. This time we will draw a green rectangle at the top-right corner of image.

# %%
img3 = cv2.imread('train_1b.png')
cv2.rectangle(img3, (60,175), (150,200), (255,0,0), 3)
plt.imshow(img3)

# %%
cv2.rectangle(img3, (150,125), (210,160), (255,0,0), 3)
plt.imshow(img3)

# %%
cv2.rectangle(img3, (50,50), (100,100), (255,0,0), -1)
plt.imshow(img3)

# %% [markdown]
# ### Drawing Circle
# To draw a circle, you need its center coordinates and radius. We will draw a circle inside the rectangle drawn above.

# %%
img3 = cv2.imread('train_1b.png')
cv2.circle(img3, (100,175), 35, (255,0,0), 3)
plt.imshow(img3)

# %% [markdown]
# ## Adding Text to Images:
# To put texts in images, you need specify following things:
# - Text data that you want to write
# - Position coordinates of where you want put it (i.e. bottom-left corner where data starts).
# - Font type (Check cv2.putText() docs for supported fonts)
# - Font Scale (specifies the size of font)
# - regular things like color, thickness, lineType etc. For better look, lineType = cv2.LINE_AA is recommended.

# %%
img3 = cv2.imread('train_1b.png')
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img3, "Hello OpenCV!", (25,75), font, 1, (255,255,255),2,cv2.LINE_AA)
plt.imshow(img3)
