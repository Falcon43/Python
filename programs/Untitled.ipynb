# %%
import re
import urllib3
http = urllib3.PoolManager()

webCrawl = http.request('GET', "https://www.coursera.org/instructor/andrewng")
webCrawlString = webCrawl.data.decode('utf-8')
print(webCrawlString)   
#print(re.findall('<title>(.*?)</title>', webCrawlString, re.DOTALL))
# Out:
# /Users/aishwaya/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# ...

# %%
webCrawl = http.request('GET', "https://www.coursera.org/instructor/andrewng")
#webCrawlString = webCrawl.data.decode('utf-8')
try:
    urlopen(webCrawlx)
    return True
except URLError:
    return False
print(webCrawlString)
# Out:
# ---------------------------------------------------------------------------
# LocationParseError                        Traceback (most recent call last)
# <ipython-input-8-1eeda7a0e6c7> in <module>()
#       1
# ----> 2 webCrawl = http.request('GET', "https:*")
#       3 webCrawlString = webCrawl.data.decode('utf-8')
#       4 print(webCrawlString)
#
# /Users/aishwaya/anaconda2/lib/python2.7/site-packages/urllib3/request.pyc in request(self, method, url, fields, headers, **urlopen_kw)
#      64             return self.request_encode_url(method, url, fields=fields,
#      65                                            headers=headers,
# ---> 66                                            **urlopen_kw)
#      67         else:
#      68             return self.request_encode_body(method, url, fields=fields,
#
# /Users/aishwaya/anaconda2/lib/python2.7/site-packages/urllib3/request.pyc in request_encode_url(self, method, url, fields, headers, **urlopen_kw)
# ...
