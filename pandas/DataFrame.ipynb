# %%
import pandas as pd
import os

# %%
# check if the files in current directory
os.listdir()
# Out:
# ['DataFrame.ipynb', 'train.csv', '.ipynb_checkpoints', 'basicapis.ipynb']

# %%
train = pd.read_csv("train.csv")

# %%
train.head()
# Out:
#    image_id    label
# 0  train_1a     rice
# 1  train_1b    candy
# 2  train_1c      jam
# 3  train_1d   coffee
# 4  train_2a  vinegar

# %%
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df = pd.DataFrame(train)
print(df)
# Out:
#         image_id        label
# 0       train_1a         rice
# 1       train_1b        candy
# 2       train_1c          jam
# 3       train_1d       coffee
# 4       train_2a      vinegar
# 5       train_2b    chocolate
# 6       train_2c        sugar
# 7       train_2d        water
# 8       train_3a        juice
# 9       train_3b        candy
# 10      train_3c        juice
# 11      train_3d        juice
# 12      train_4a        candy
# 13      train_4b         milk
# 14      train_4c       coffee
# 15      train_4d         rice
# 16      train_5a    chocolate
# 17      train_5b         soda
# 18      train_5c        juice
# 19      train_5d         nuts
# 20      train_6a        chips
# 21      train_6b       spices
# 22      train_6c       cereal
# 23      train_6d        chips
# 24      train_7a         milk
# 25      train_7b       cereal
# 26      train_7c        candy
# 27      train_7d    chocolate
# 28      train_8a        beans
# 29      train_8b         cake
# ...          ...          ...
# 3185  train_797b         rice
# 3186  train_797c         rice
# 3187  train_797d        water
# 3188  train_798a       coffee
# 3189  train_798b         nuts
# 3190  train_798c        candy
# 3191  train_798d  tomatosauce
# 3192  train_799a         fish
# 3193  train_799b        honey
# 3194  train_799c       spices
# 3195  train_799d  tomatosauce
# 3196  train_800a       cereal
# 3197  train_800b         cake
# 3198  train_800c          oil
# 3199  train_800d      vinegar
# 3200  train_801a          tea
# 3201  train_801b        water
# 3202  train_801c        candy
# 3203  train_801d        juice
# 3204  train_802a        water
# 3205  train_802b          jam
# 3206  train_802c        honey
# 3207  train_802d       coffee
# 3208  train_803a        juice
# 3209  train_803b  tomatosauce
# 3210  train_803c         soda
# 3211  train_803d       spices
# 3212  train_804a         nuts
# 3213  train_804b        candy
# 3214  train_804c       coffee
#
# [3215 rows x 2 columns]

# %%
#A random 100% sample of the DataFrame :
df.sample(frac=1)
# Out:
#         image_id        label
# 2795  train_699d      vinegar
# 1780  train_446a        honey
# 163    train_41d       spices
# 232    train_59a         soda
# 2289  train_573b  tomatosauce
# 7       train_2d        water
# 1278  train_320c         fish
# 958   train_240c          jam
# 2075  train_519d         rice
# 2339  train_585d        pasta
# 1881  train_471b        sugar
# 2713  train_679b        beans
# 2916  train_730a      vinegar
# 2993  train_749b       spices
# 305    train_77b      vinegar
# 34      train_9c       coffee
# 683   train_171d  tomatosauce
# 2674  train_669c         soda
# 399   train_100d       spices
# 3145  train_787b        sugar
# 3118  train_780c        water
# 2249  train_563b        juice
# 2079  train_520d        pasta
# 1944  train_487a        pasta
# 3202  train_801c        candy
# 53     train_14b         rice
# 2730  train_683c       coffee
# 3093  train_774b         nuts
# 1264  train_317a       spices
# 2138  train_535c        water
# ...          ...          ...
# 2063  train_516d          oil
# 2699  train_675d          jam
# 1312  train_329a       spices
# 2281  train_571b         fish
# 196    train_50a        honey
# 1129  train_283b         soda
# 95     train_24d       cereal
# 2843  train_711d       cereal
# 826   train_207c         soda
# 2609  train_653b         cake
# 1227  train_307d          tea
# 1584  train_397a    chocolate
# 2313  train_579b       cereal
# 139    train_35d         rice
# 2781  train_696b          tea
# 253    train_64b        candy
# 2612  train_654a       spices
# 96     train_25a        flour
# 1924  train_482a          jam
# 850   train_213c        water
# 1133  train_284b        water
# 1648  train_413a        juice
# 2754  train_689c        candy
# 1513  train_379b         nuts
# 2317  train_580b       cereal
# 601   train_151b        flour
# 2357  train_590b       coffee
# 3063  train_766d          tea
# 1700  train_426a       cereal
# 107    train_27d         cake
#
# [3215 rows x 2 columns]

# %%
#A random 50% sample of the DataFrame :
df.sample(frac=0.5)
# Out:
#         image_id        label
# 2223  train_556d         corn
# 2224  train_557a        pasta
# 3168  train_793a       cereal
# 2892  train_724a        juice
# 1697  train_425b         cake
# 946   train_237c        flour
# 2168  train_543a          jam
# 2448  train_613a        pasta
# 3039  train_760d    chocolate
# 1866  train_467c       coffee
# 2534  train_634c         soda
# 2893  train_724b    chocolate
# 558   train_140c        flour
# 1621  train_406b       cereal
# 25      train_7b       cereal
# 1891  train_473d          jam
# 1199  train_300d        candy
# 102    train_26c         soda
# 255    train_64d      vinegar
# 1643  train_411d      vinegar
# 2318  train_580c         nuts
# 1262  train_316c         milk
# 2303  train_576d  tomatosauce
# 281    train_71b  tomatosauce
# 75     train_19d        honey
# 1422  train_356c        pasta
# 2832  train_709a         soda
# 509   train_128b    chocolate
# 1809  train_453b         milk
# 2968  train_743a       spices
# ...          ...          ...
# 2477  train_620b    chocolate
# 790   train_198c         corn
# 3007  train_752d        candy
# 1425  train_357b        candy
# 157    train_40b       coffee
# 2673  train_669b        candy
# 1545  train_387b        beans
# 2881  train_721b        water
# 754   train_189c    chocolate
# 2946  train_737c        juice
# 1165  train_292b         cake
# 2889  train_723b       spices
# 3113  train_779b      vinegar
# 2860  train_716a    chocolate
# 1093  train_274b    chocolate
# 713   train_179b       coffee
# 2384  train_597a       cereal
# 2164  train_542a        juice
# 1601  train_401b        beans
# 249    train_63b       coffee
# 709   train_178b         milk
# 999   train_250d        chips
# 1076  train_270a       cereal
# 2314  train_579c          tea
# 2038  train_510c       cereal
# 368    train_93a          jam
# 56     train_15a          tea
# 2842  train_711c         nuts
# 338    train_85c        juice
# 2807  train_702d        water
#
# [1608 rows x 2 columns]

# %% [markdown]
# # How do I create test and train samples from one dataframe with pandas?

# %%
print(df)
# Out:
#         image_id        label
# 0       train_1a         rice
# 1       train_1b        candy
# 2       train_1c          jam
# 3       train_1d       coffee
# 4       train_2a      vinegar
# 5       train_2b    chocolate
# 6       train_2c        sugar
# 7       train_2d        water
# 8       train_3a        juice
# 9       train_3b        candy
# 10      train_3c        juice
# 11      train_3d        juice
# 12      train_4a        candy
# 13      train_4b         milk
# 14      train_4c       coffee
# 15      train_4d         rice
# 16      train_5a    chocolate
# 17      train_5b         soda
# 18      train_5c        juice
# 19      train_5d         nuts
# 20      train_6a        chips
# 21      train_6b       spices
# 22      train_6c       cereal
# 23      train_6d        chips
# 24      train_7a         milk
# 25      train_7b       cereal
# 26      train_7c        candy
# 27      train_7d    chocolate
# 28      train_8a        beans
# 29      train_8b         cake
# ...          ...          ...
# 3185  train_797b         rice
# 3186  train_797c         rice
# 3187  train_797d        water
# 3188  train_798a       coffee
# 3189  train_798b         nuts
# 3190  train_798c        candy
# 3191  train_798d  tomatosauce
# 3192  train_799a         fish
# 3193  train_799b        honey
# 3194  train_799c       spices
# 3195  train_799d  tomatosauce
# 3196  train_800a       cereal
# 3197  train_800b         cake
# 3198  train_800c          oil
# 3199  train_800d      vinegar
# 3200  train_801a          tea
# 3201  train_801b        water
# 3202  train_801c        candy
# 3203  train_801d        juice
# 3204  train_802a        water
# 3205  train_802b          jam
# 3206  train_802c        honey
# 3207  train_802d       coffee
# 3208  train_803a        juice
# 3209  train_803b  tomatosauce
# 3210  train_803c         soda
# 3211  train_803d       spices
# 3212  train_804a         nuts
# 3213  train_804b        candy
# 3214  train_804c       coffee
#
# [3215 rows x 2 columns]

# %%
train_random = df.sample(frac=0.8,random_state=200)
test_random = df.drop(train_random.index)

# %%
print(train_random)
# Out:
#         image_id        label
# 1905  train_477b        sugar
# 2919  train_730d       coffee
# 2485  train_622b          jam
# 2880  train_721a      vinegar
# 1792  train_449a          jam
# 36     train_10a          jam
# 1996  train_500a        flour
# 1886  train_472c  tomatosauce
# 4       train_2a      vinegar
# 900   train_226a          jam
# 3129  train_783b       coffee
# 3105  train_777b         nuts
# 525   train_132b          oil
# 1828  train_458a         fish
# 3183  train_796d        candy
# 1149  train_288b         corn
# 2304  train_577a        juice
# 2499  train_625d          tea
# 8       train_3a        juice
# 2682  train_671c         corn
# 1089  train_273b         cake
# 1166  train_292c          tea
# 2712  train_679a       cereal
# 1558  train_390c         cake
# 2786  train_697c         nuts
# 245    train_62b         cake
# 1429  train_358b          tea
# 408   train_103a      vinegar
# 228    train_58a         milk
# 113    train_29b  tomatosauce
# ...          ...          ...
# 2965  train_742b  tomatosauce
# 2669  train_668b       spices
# 261    train_66b        beans
# 3148  train_788a      vinegar
# 2169  train_543b       spices
# 2196  train_550a       spices
# 2537  train_635b        water
# 144    train_37a        honey
# 2086  train_522c          oil
# 2850  train_713c       coffee
# 2482  train_621c         rice
# 80     train_21a          tea
# 1793  train_449b        beans
# 2549  train_638b          oil
# 334    train_84c         corn
# 3192  train_799a         fish
# 3162  train_791c    chocolate
# 2578  train_645c        flour
# 1070  train_268c      vinegar
# 392    train_99a        pasta
# 2134  train_534c         milk
# 2648  train_663a        chips
# 1949  train_488b    chocolate
# 1446  train_362c      vinegar
# 487   train_122d        candy
# 3085  train_772b        honey
# 3091  train_773d        juice
# 842   train_211c        candy
# 84     train_22a         milk
# 48     train_13a        chips
#
# [2572 rows x 2 columns]

# %%
print(test_random)
# Out:
#         image_id        label
# 17      train_5b         soda
# 18      train_5c        juice
# 67     train_17d        flour
# 73     train_19b         soda
# 76     train_20a       coffee
# 89     train_23b         fish
# 90     train_23c        chips
# 91     train_23d        juice
# 94     train_24c         corn
# 102    train_26c         soda
# 106    train_27c          tea
# 111    train_28d         rice
# 124    train_32a    chocolate
# 130    train_33c    chocolate
# 137    train_35b    chocolate
# 140    train_36a    chocolate
# 145    train_37b    chocolate
# 146    train_37c          tea
# 153    train_39b        candy
# 159    train_40d         rice
# 162    train_41c  tomatosauce
# 169    train_43b         rice
# 174    train_44c         rice
# 175    train_44d        juice
# 178    train_45c        candy
# 184    train_47a        beans
# 185    train_47b        chips
# 188    train_48a         nuts
# 189    train_48b        pasta
# 190    train_48c         rice
# ...          ...          ...
# 3078  train_770c        water
# 3079  train_770d        juice
# 3082  train_771c        honey
# 3087  train_772d          tea
# 3092  train_774a        juice
# 3095  train_774d         soda
# 3098  train_775c       cereal
# 3101  train_776b         fish
# 3102  train_776c          jam
# 3104  train_777a       cereal
# 3107  train_777d          tea
# 3110  train_778c         nuts
# 3112  train_779a  tomatosauce
# 3113  train_779b      vinegar
# 3114  train_779c         corn
# 3119  train_780d         rice
# 3123  train_781d       spices
# 3135  train_784d    chocolate
# 3137  train_785b         soda
# 3143  train_786d        chips
# 3151  train_788d       spices
# 3153  train_789b        candy
# 3172  train_794a       coffee
# 3173  train_794b    chocolate
# 3174  train_794c         fish
# 3180  train_796a          tea
# 3185  train_797b         rice
# 3188  train_798a       coffee
# 3206  train_802c        honey
# 3207  train_802d       coffee
#
# [643 rows x 2 columns]
